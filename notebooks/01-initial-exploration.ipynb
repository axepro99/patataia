# %% [markdown]
# ## 1. Exploración Inicial de Datos (EDA)
#
# El objetivo de este notebook es realizar un primer análisis de los datasets de patrones de velas y gráficos.
#
# **Pasos:**
# 1. Cargar los datos usando pandas.
# 2. Inspeccionar las primeras filas (`.head()`).
# 3. Revisar los tipos de datos y valores nulos (`.info()`).
# 4. Obtener estadísticas descriptivas (`.describe()`).
# 5. Visualizar algunas de las características para entender su distribución.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

sns.set_style('darkgrid')

# Ajusta esta ruta si es necesario
DATA_PATH = '../data/'

# %% [markdown]
# ### Cargar el Dataset de Patrones de Gráficos de Bolsa

# %%
# ¡IMPORTANTE! Debes reemplazar 'nombre_del_fichero.csv' con el nombre real del archivo del dataset
file_path = os.path.join(DATA_PATH, 'stock-chart-patterns', 'nombre_del_fichero.csv')

try:
    df_stock = pd.read_csv(file_path)
    print("Dataset de patrones de gráficos cargado con éxito.")
    display(df_stock.head())
except FileNotFoundError:
    print(f"Error: El fichero no se encuentra en {file_path}")
    print("Por favor, asegúrate de haber descargado los datos en la carpeta /data y de que el nombre del fichero es correcto.")

# %%
# Ver información del DataFrame
if 'df_stock' in locals():
    df_stock.info()
